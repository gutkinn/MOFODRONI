# %%
import prepare_country_VICI
import os
from pathlib import Path

main_dir = Path(os.getcwd()).parent

stack_file = os.path.join("Output","stacks","invalid_pixel_stack.tif")

prepare_country_VICI.get_harmonic_cube(stack_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import prepare_country_VICI
#       2 import os
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'prepare_country_VICI'
